# %%
import pandas as pd
import numpy as np

# %%
data = 'C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/API HW/HW_TABLE.csv'

# %%
data_df = pd.read_csv(data)

# %%
data_df.head()
# Out:
#    Unnamed: 0        City Country  Latitude  Longitude  Temperature  \
# 0           0      kenora      ca     49.76     -94.48         2.00
# 1           1      kasama      zm    -10.21      31.19        18.77
# 2           2     madimba      tz    -10.40      40.33        25.42
# 3           4  hambantota      lk      6.12      81.12        25.67
# 4           5     oneonta      us     42.45     -75.06         6.05
#
#    Wind Speed  Humidity  Cloudiness
# 0        2.60      69.0        75.0
# 1        5.57      46.0         0.0
# 2        8.52      98.0         0.0
# 3        2.97     100.0        88.0
# 4        1.77     100.0        92.0

# %%
html_table = data_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Wind Speed</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>kenora</td>\n      <td>ca</td>\n      <td>49.76</td>\n      <td>-94.48</td>\n      <td>2.00</td>\n      <td>2.60</td>\n      <td>69.0</td>\n      <td>75.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>kasama</td>\n      <td>zm</td>\n      <td>-10.21</td>\n      <td>31.19</td>\n      <td>18.77</td>\n      <td>5.57</td>\n      <td>46.0</td>\n      <td>0.0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>madimba</td>\n      <td>tz</td>\n      <td>-10.40</td>\n      <td>40.33</td>\n      <td>25.42</td>\n      <td>8.52</td
# ...
